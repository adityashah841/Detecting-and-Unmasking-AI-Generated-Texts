# %%
# !pip install gpt4all

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gpt4all
#gptj = gpt4all.GPT4All("ggml-gpt4all-j-v1.3-groovy")
from gpt4all import GPT4All
model = GPT4All("orca-mini-3b.ggmlv3.q4_0.bin")
# Out:
# Found model file at  /root/.cache/gpt4all/orca-mini-3b.ggmlv3.q4_0.bin

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/aiGenTxt/GPT-wiki-intro.csv')

# %%
df.head()
# Out:
#          id                                                url  \
# 0  63064638  https://en.wikipedia.org/wiki/Sexhow%20railway...
# 1    279621        https://en.wikipedia.org/wiki/Eti%C3%A4inen
# 2    287229  https://en.wikipedia.org/wiki/Inverse%20functi...
# 3  26712375  https://en.wikipedia.org/wiki/Stepping%20on%20...
# 4  38894426        https://en.wikipedia.org/wiki/Rob%20Bradley
#
#                       title  \
# 0    Sexhow railway station
# 1                  Etiäinen
# 2  Inverse function theorem
# 3         Stepping on Roses
# 4               Rob Bradley
#
#                                           wiki_intro  \
# 0  Sexhow railway station was a railway station b...
# 1  In Finnish folklore, all places and things, an...
# 2  In mathematics, specifically differential calc...
# 3  is a Japanese shōjo manga series written and i...
# 4  Robert Milner "Rob" Bradley, Jr. (born August ...
#
#                                      generated_intro  title_len  \
# ...

# %%
question = df['prompt'][0]
response = model.generate(question)
# Out:
# Exception ignored on calling ctypes callback function: <function LLModel._callback_decoder.<locals>._raw_callback at 0x79a7dbba36d0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gpt4all/pyllmodel.py", line 373, in _raw_callback
#     def _raw_callback(token_id: int, response: bytes) -> bool:
# KeyboardInterrupt:
# Exception ignored on calling ctypes callback function: <function LLModel._callback_decoder.<locals>._raw_callback at 0x79a7dbba36d0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gpt4all/pyllmodel.py", line 373, in _raw_callback
#     def _raw_callback(token_id: int, response: bytes) -> bool:
# KeyboardInterrupt:

# %%
response

# %%
gptj_gen=[]

for i in range(250, 300):
  gptj_gen.append(model.generate(df['prompt'][i]))
  print(i)
# Out:
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299

# %%
df_gptj = pd.DataFrame(gptj_gen)
df_gptj.to_csv('/content/drive/MyDrive/aiGenTxt/Orca_Gen_250-300.csv')

# %%
print(df_gptj[0][0])
# Out:
#  15, 1793) was a French painter and engraver. He is best known for his portraits of the aristocracy during the 18th century in France. Born into an artistic family, he began painting at age 16 with lessons from Jean-Baptiste Greuze. In 1762, Saint-Martin married Marie-Louise de La Grange d'Armenonville and they had six children together. He was a member of the Académie Royale des Sciences et Belles Lettres in Paris where he served as its president from 1774 to 1775.
